# %% [markdown]
# <a href="https://colab.research.google.com/github/ritwika2000/Political_sentiment_analysis/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout
import re
from nltk.corpus import stopwords
from nltk import word_tokenize
import nltk
import tensorflow as tf
import numpy as np
import pandas as pd
nltk.download('stopwords')
STOPWORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
path='drive/MyDrive/dataset.csv'
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0                                          full_text  hashtags  \
# 0           0  guwahati gain lot promin recent year due pm sh...   ActEast
# 1           1  rss school day indoctrin sinc childhood thrice...       NaN
# 2           2  word dont exist vaccummodi post pulwama word g...       NaN
# 3           3  india icecream industri stand  crore fastest g...  Icecream
# 4           4   crpf jawan kill pulwama attackiaf strike paki...       NaN
#
#     subject                                          sentiment  \
# 0       Bjp  {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'comp...
# 1       Bjp  {'neg': 0.421, 'neu': 0.458, 'pos': 0.121, 'co...
# 2       Bjp  {'neg': 0.114, 'neu': 0.886, 'pos': 0.0, 'comp...
# 3  Congress  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       Bjp  {'neg': 0.396, 'neu': 0.604, 'pos': 0.0, 'comp...
#
#   sentiment_overall   total_sentiment
# 0          Positive      Bjp_Positive
# 1          Negative      Bjp_Negative
# ...

# %%
new_data=df[['full_text','sentiment_overall']]
new_data.head()
# Out:
#                                            full_text sentiment_overall
# 0  guwahati gain lot promin recent year due pm sh...          Positive
# 1  rss school day indoctrin sinc childhood thrice...          Negative
# 2  word dont exist vaccummodi post pulwama word g...          Negative
# 3  india icecream industri stand  crore fastest g...           Neutral
# 4   crpf jawan kill pulwama attackiaf strike paki...          Negative

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):

    text = str(text).lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    text = text.replace('x', '')
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text

new_data['full_text'] = new_data['full_text'].apply(clean_text)
new_data['full_text']=new_data['full_text'].str.replace('\d+', '')
# Out:
# <ipython-input-5-9317db88120f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['full_text'] = new_data['full_text'].apply(clean_text)
# <ipython-input-5-9317db88120f>:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_data['full_text']=new_data['full_text'].str.replace('\d+', '')
# <ipython-input-5-9317db88120f>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# The maximum number of words to be used. (most frequent)
MAX_NB_WORDS = 50000
# Max number of words in each complaint.
MAX_SEQUENCE_LENGTH = 250
# This is fixed.
EMBEDDING_DIM = 100

tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(new_data['full_text'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 75606 unique tokens.

# %%
X = tokenizer.texts_to_sequences(new_data['full_text'].values)
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', X.shape)
# Out:
# Shape of data tensor: (46043, 250)

# %%
Y = pd.get_dummies(new_data['sentiment_overall']).values
print('Shape of label tensor:', Y.shape)
# Out:
# Shape of label tensor: (46043, 3)

# %%
print(Y)
# Out:
# [[0 0 1]
#  [1 0 0]
#  [1 0 0]
#  ...
#  [0 1 0]
#  [1 0 0]
#  [1 0 0]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.10, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (41438, 250) (41438, 3)
# (4605, 250) (4605, 3)

# %%
model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 250, 100)          5000000
#
#  spatial_dropout1d_1 (Spatia  (None, 250, 100)         0
#  lDropout1D)
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense_1 (Dense)             (None, 3)                 303
#
# ...
# Total params: 5,080,703
# Trainable params: 5,080,703
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epochs = 3
batch_size = 64

history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
# Out:
# Epoch 1/3
# 583/583 [==============================] - 525s 893ms/step - loss: 0.5671 - accuracy: 0.7681 - val_loss: 0.2952 - val_accuracy: 0.9095
# Epoch 2/3
# 583/583 [==============================] - 523s 898ms/step - loss: 0.2206 - accuracy: 0.9354 - val_loss: 0.2594 - val_accuracy: 0.9192
# Epoch 3/3
# 583/583 [==============================] - 508s 872ms/step - loss: 0.1570 - accuracy: 0.9543 - val_loss: 0.3035 - val_accuracy: 0.9073

# %%
accr = model.evaluate(X_test,Y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 144/144 [==============================] - 31s 215ms/step - loss: 0.3288 - accuracy: 0.8988
# Test set
#   Loss: 0.329
#   Accuracy: 0.899

# %%
KERAS_MODEL_NAME = "model_sen.h5"
model.save(KERAS_MODEL_NAME)

# %%
new_model = tf.keras.models.load_model('drive/MyDrive/model_sen.h5')

# Check its architecture
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 250, 100)          5000000
#
#  spatial_dropout1d_1 (Spatia  (None, 250, 100)         0
#  lDropout1D)
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense_1 (Dense)             (None, 3)                 303
#
# ...
# Total params: 5,080,703
# Trainable params: 5,080,703
# Non-trainable params: 0
# _________________________________________________________________

# %%
path='drive/MyDrive/final_toi.csv'
news=pd.read_csv(path)
news.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                Title                Time  \
# 0  Covid-19 numbers will rise for 10-12 days, the...  17 Mar 2023, 10:34
# 1  ‘Won’t wait for panel’, SC to rule on quota fo...  16 Mar 2023, 22:37
# 2  Why Rahul can't win against Modi on democracy ...  15 Mar 2023, 19:46
# 3  Bathinda military station firing: What we know...  14 Mar 2023, 22:34
# 4  Live: India logs over 10k cases in 24 hours, h...  14 Mar 2023, 22:26
#
#                                                  URL           Paper  \
# 0  /india/covid-numbers-will-rise-for-10-12-days-...  Times of India
# 1  /india/wont-wait-for-panel-sc-to-rule-on-quota...  Times of India
# 2  /india/has-congress-misread-the-national-mood-...  Times of India
# 3  /city/chandigarh/bathinda-military-station-fir...  Times of India
# ...

# %%
news=news[['Title','Sentiment']]
news.head()
# Out:
#                                                Title Sentiment
# 0  Covid-19 numbers will rise for 10-12 days, the...   Neutral
# 1  ‘Won’t wait for panel’, SC to rule on quota fo...   Neutral
# 2  Why Rahul can't win against Modi on democracy ...  Negative
# 3  Bathinda military station firing: What we know...  Negative
# 4  Live: India logs over 10k cases in 24 hours, h...   Neutral

# %%
i=0;
score=0;

for sen in news['Title']:
  sen=[sen]
  seq = tokenizer.texts_to_sequences(sen)
  padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
  pred = new_model.predict(padded)
  labels = ['Negative','Neutral','Positive']
  if(labels[np.argmax(pred)]==news['Sentiment'][i]):
    score+=1
  i+=1

print(score/1000)
# Out:
# ...
# 1/1 [==============================] - 0s 49ms/step
# 0.673
